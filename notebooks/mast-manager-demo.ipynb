# %%
from mast_aladin.managers import MastManager
from mast_aladin import MastAladin

import warnings

# %%
mm = MastManager()

# %%
aladin_viewer_a = MastAladin(target="Cartwheel Galaxy", height=400)
aladin_viewer_b = MastAladin(target="Cartwheel Galaxy", height=400)
aladin_viewer_c = MastAladin(target="Cartwheel Galaxy", height=400)


mm.register_app(aladin_viewer_a, "aladin_a")
mm.register_app(aladin_viewer_b, "aladin_b")
mm.register_app(aladin_viewer_c, "aladin_c")

# %%
mm.open()
